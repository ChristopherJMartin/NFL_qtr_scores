# %% [markdown]
# ---
#
#
# ## Common types of time series forecasting problems
#
# - Forecast a single value of the time series. (use y historic values of y to predict y at one point in the future)
# - Forecast a whole range of future values. (use historic values of y to predict y at many points in the future)
# - Use other features to aid in your forecast. (predict many y in the future and use y and X)
# - Forecast multiple time series simultaneously

# %% [markdown]
# ## Approaching time series forecasting problems

# %% [markdown]
# ## Before modeling
# - Get the time period into *datetime* dtype format
# - put it in the index
# - sort the index
#
# ## Modeling considerations
# - Make sure you are clear what you are predicting (one value, a range of values, one-step-ahead that updates every time period?)
# - **Make sure you aren't leaking information from the future into your training data**
# - Make null baseline models

# %% [markdown]
# ## Quarter Scores

# %% [markdown]
# ### Let's forecast one single value one time period into the future

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Prepare data

# %% [markdown]
# #### Read in the dataset, set the index as a datetime index, sort it, and take a look at it.

# %%
games = pd.read_csv('data/MasterGames_2000to2019.csv')
games.head()
# Out:
#          GameID  Week  Day   DateStamp     Vteam  VQ1  VQ2  VQ3  VQ4  Year  \
# 0  200009030min     1  Sun  2000-09-03     Bears    7    6    7    7  2000
# 1  200009030kan     1  Sun  2000-09-03     Colts    0    7    7   13  2000
# 2  200009030was     1  Sun  2000-09-03  Panthers   10    0    0    7  2000
# 3  200009030atl     1  Sun  2000-09-03     49ers    7    7    7    7  2000
# 4  200009030pit     1  Sun  2000-09-03    Ravens   10    3    3    0  2000
#
#       Hteam  HQ1  HQ2  HQ3  HQ4      Date    Time           Winner/tie  \
# 0   Vikings    6    3    7   14  9/3/2000  1:00PM    Minnesota Vikings
# 1    Chiefs    0    7    7    0  9/3/2000  1:00PM   Indianapolis Colts
# 2  Redskins    7    0    3   10  9/3/2000  1:01PM  Washington Redskins
# 3   Falcons    6   16   14    0  9/3/2000  1:02PM      Atlanta Falcons
# 4  Steelers    0    0    0    0  9/3/2000  1:02PM     Baltimore Ravens
#
#   Unnamed: 18            Loser/tie
# 0         NaN        Chicago Bears
# 1           @   Kansas City Chiefs
# 2         NaN    Carolina Panthers
# 3         NaN  San Francisco 49ers
# 4           @  Pittsburgh Steelers

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5324 entries, 0 to 5323
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GameID       5324 non-null   object
#  1   Week         5324 non-null   int64
#  2   Day          5324 non-null   object
#  3   DateStamp    5324 non-null   object
#  4   Vteam        5324 non-null   object
#  5   VQ1          5324 non-null   int64
#  6   VQ2          5324 non-null   int64
#  7   VQ3          5324 non-null   int64
#  8   VQ4          5324 non-null   int64
#  9   Year         5324 non-null   int64
#  10  Hteam        5324 non-null   object
#  11  HQ1          5324 non-null   int64
#  12  HQ2          5324 non-null   int64
#  13  HQ3          5324 non-null   int64
#  14  HQ4          5324 non-null   int64
#  15  Date         5324 non-null   object
#  16  Time         5324 non-null   object
#  17  Winner/tie   5324 non-null   object
#  18  Unnamed: 18  2296 non-null   object
#  19  Loser/tie    5324 non-null   object
# dtypes: int64(10), object(10)
# memory usage: 832.0+ KB

# %%
games.tail()
# Out:
#             Unnamed: 0                GameID  Week  Day    Vteam  VQ1  VQ2  \
# DateStamp
# 2020-01-12        5319  2019-DV-Vikings49ers   200  Sun  Vikings    7    3
# 2020-01-12        5320  2019-DV-TitansRavens   200  Sun   Titans    7    7
# 2020-01-19        5321  2019-CC-TitansChiefs   300  Sun   Titans   10    7
# 2020-01-19        5322  2019-CC-Packers49ers   300  Sun  Packers    0    0
# 2020-02-02        5323   2019-SB-49ersChiefs   400  Sun    49ers    3    7
#
#             VQ3  VQ4  Year   Hteam  HQ1  HQ2  HQ3  HQ4       Date    Time  \
# DateStamp
# 2020-01-12    0    0  2019   49ers    7    7   10    3  1/12/2020  3:05PM
# 2020-01-12   14    0  2019  Ravens    0    6    0    6  1/12/2020  6:40PM
# 2020-01-19    0    7  2019  Chiefs    7   14    0   14  1/19/2020  3:05PM
# 2020-01-19    7   13  2019   49ers    7   20    7    3  1/19/2020  6:40PM
# 2020-02-02   10    0  2019  Chiefs    7    3    0   21   2/2/2020  6:30PM
#
#                      Winner/tie Unnamed: 18            Loser/tie
# DateStamp
# 2020-01-12   Kansas City Chiefs         NaN       Houston Texans
# 2020-01-12    Green Bay Packers         NaN     Seattle Seahawks
# 2020-01-19   Kansas City Chiefs         NaN     Tennessee Titans
# 2020-01-19  San Francisco 49ers         NaN    Green Bay Packers
# 2020-02-02   Kansas City Chiefs           N  San Francisco 49ers

# %%
games.columns
# Out:
# Index(['Unnamed: 0', 'GameID', 'Week', 'Day', 'Vteam', 'VQ1', 'VQ2', 'VQ3',
#        'VQ4', 'Year', 'Hteam', 'HQ1', 'HQ2', 'HQ3', 'HQ4', 'Date', 'Time',
#        'Winner/tie', 'Unnamed: 18', 'Loser/tie'],
#       dtype='object')

# %% [markdown]
# #### Keep only quarter scores

# %%
games_Qscores = games[['VQ1', 'VQ2', 'VQ3','VQ4', 'HQ1', 'HQ2', 'HQ3', 'HQ4']]
games_Qscores
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4
# DateStamp
# 2000-09-03    7    6    7    7    6    3    7   14
# 2000-09-03    0    7    7   13    0    7    7    0
# 2000-09-03   10    0    0    7    7    0    3   10
# 2000-09-03    7    7    7    7    6   16   14    0
# 2000-09-03   10    3    3    0    0    0    0    0
# ...         ...  ...  ...  ...  ...  ...  ...  ...
# 2020-01-12    7    3    0    0    7    7   10    3
# 2020-01-12    7    7   14    0    0    6    0    6
# 2020-01-19   10    7    0    7    7   14    0   14
# 2020-01-19    0    0    7   13    7   20    7    3
# 2020-02-02    3    7   10    0    7    3    0   21
#
# [5324 rows x 8 columns]

# %% [markdown]
# ### Split the dataset into train and test sets.

# %% [markdown]
# Subset the data to train and test. **The test set must come after the training set.**
#
# #### Let's make the two datasets manually

# %%
train = games_Qscores.loc[:'2015']
test = games_Qscores.loc['2015':'2018']

# %%
test
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4
# DateStamp
# 2015-01-03    0   14    0    2   10    3   14    0
# 2015-01-03    0   10   10   10    3    6    0    8
# 2015-01-04    7    3    0    0    7    6   10    3
# 2015-01-04   14    3    3    0    0    7    7   10
# 2015-01-10   14    7    7    3    7    7   14    7
# ...         ...  ...  ...  ...  ...  ...  ...  ...
# 2018-12-30    3    7    0    0    0    9    3    3
# 2018-12-30    7    0    0    7    0   21    7    7
# 2018-12-30    0   14    3    3    3    7    0   14
# 2018-12-30    7    0    0    0    7   17    7    7
# 2018-12-30    9   13    7   12    3    9   14    7
#
# [1068 rows x 8 columns]

# %%
# just for fun - plot VQ1s
train['VQ1'].plot()
test['VQ1'].plot();

# %% [markdown]
# Plot the two DataFrames

# %% [markdown]
# ## Model 1: Naive Forecast

# %% [markdown]
# Take the last time period's sales and estimate the same value for all future time periods. This method is a **naive forecast**.
#
# $${\Large \hat y_{t+1} = y_t}$$

# %% [markdown]
# Make a predictions DataFrame and set the predicted values equal to the last value in the `Sales` df.

# %%
train.tail(1)
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4
# DateStamp
# 2015-12-28    7   10    0    3    7    3    2    8

# %% [markdown]
# #### Save our results in a *df_predictions* DataFrame.

# %%
df_predictions = test.copy(deep=True)

# %%
df_predictions.shape
# Out:
# (1068, 8)

# %% [markdown]
# #### Take the last training dataset value and make that the guess for all future time periods.

# %%
df_predictions['lastVQ1'] = train['VQ1'].iloc[-1]

# %%
df_predictions
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4  lastVQ1
# DateStamp
# 2015-01-03    0   14    0    2   10    3   14    0        7
# 2015-01-03    0   10   10   10    3    6    0    8        7
# 2015-01-04    7    3    0    0    7    6   10    3        7
# 2015-01-04   14    3    3    0    0    7    7   10        7
# 2015-01-10   14    7    7    3    7    7   14    7        7
# ...         ...  ...  ...  ...  ...  ...  ...  ...      ...
# 2018-12-30    3    7    0    0    0    9    3    3        7
# 2018-12-30    7    0    0    7    0   21    7    7        7
# 2018-12-30    0   14    3    3    3    7    0   14        7
# 2018-12-30    7    0    0    0    7   17    7    7        7
# 2018-12-30    9   13    7   12    3    9   14    7        7
#
# [1068 rows x 9 columns]

# %% [markdown]
# #### Plot the historic data, the actual "future" data, and the predicted "future" data.

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['VQ1'], label='Train')
plt.plot(test.index, test['VQ1'], label='Test')
plt.plot(df_predictions.index, df_predictions['lastVQ1'], label="Naive Last")

plt.legend(loc='best')
plt.title("Naive Forecast");

# %% [markdown]
# #### Score our model

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df_predictions['VQ1'], df_predictions['lastVQ1'], squared=False)
# Out:
# 5.28087497006303

# %% [markdown]
# #### That's the most basic baseline.

# %% [markdown]
# ---
# ## Model 2: Simple average of the training data
# Another baseline model. Maybe slightly better when the data don't have much of a trend.

# %%
df_predictions['simple_mean'] = train['VQ1'].mean()

# %% [markdown]
# #### Plot

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['VQ1'], label='Train')
plt.plot(test.index, test['VQ1'], label='Test')
plt.plot(df_predictions.index, df_predictions['lastVQ1'], label="Naive Last")
plt.plot(df_predictions.index, df_predictions['simple_mean'], label="Naive mean")

plt.legend(loc='best')
plt.title("Naive Forecast");

# %% [markdown]
# #### Evaluate

# %%
mean_squared_error(df_predictions['VQ1'], df_predictions['simple_mean'], squared=False)
# Out:
# 4.230499436574731

# %% [markdown]
# ## Model 3: Seasonality
#
# Chose 25 observations prior (263 games/yr divided by 10)ish.

# %%
df_predictions['seasonal'] = train['VQ1'].shift(25,freq='infer')
#doesn't work
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-0f0570132a85> in <module>
# ----> 1 df_predictions['seasonal'] = train['VQ1'].shift(25,freq='infer')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\series.py in shift(self, periods, freq, axis, fill_value)
#    4543     @doc(NDFrame.shift, klass=_shared_doc_kwargs["klass"])
#    4544     def shift(self, periods=1, freq=None, axis=0, fill_value=None) -> "Series":
# -> 4545         return super().shift(
#    4546             periods=periods, freq=freq, axis=axis, fill_value=fill_value
#    4547         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in shift(self, periods, freq, axis, fill_value)
#    9451             if freq is None:
#    9452                 msg = "Freq was not set in the index hence cannot be inferred"
# -> 9453                 raise ValueError(msg)
#    9454
#    9455         elif isinstance(freq, str):
#
# ValueError: Freq was not set in the index hence cannot be inferred

# %%
df_predictions
# Out:
#                  sales        last   simple_mean    seasonal
# Date
# 2012-01-06  1550369.92  1497462.72  1.542008e+06  1444732.28
# 2012-01-13  1459601.17  1497462.72  1.542008e+06  1391013.96
# 2012-01-20  1394393.84  1497462.72  1.542008e+06  1327405.42
# 2012-01-27  1319325.59  1497462.72  1.542008e+06  1316899.31
# 2012-02-03  1636339.65  1497462.72  1.542008e+06  1606629.58
# 2012-02-10  1802477.43  1497462.72  1.542008e+06  1649614.93
# 2012-02-17  1819870.00  1497462.72  1.542008e+06  1686842.78
# 2012-02-24  1539387.83  1497462.72  1.542008e+06  1456800.28
# 2012-03-02  1688420.76  1497462.72  1.542008e+06  1636263.41
# 2012-03-09  1675431.16  1497462.72  1.542008e+06  1553191.63
# 2012-03-16  1677472.78  1497462.72  1.542008e+06  1576818.06
# 2012-03-23  1511068.07  1497462.72  1.542008e+06  1541102.38
# 2012-03-30  1649604.63  1497462.72  1.542008e+06  1495064.75
# 2012-04-06  1899676.88  1497462.72  1.542008e+06  1614259.35
# 2012-04-13  1621031.70  1497462.72  1.542008e+06  1559889.00
# 2012-04-20  1521577.87  1497462.72  1.542008e+06  1564819.81
# 2012-04-27  1468928.37  1497462.72  1.542008e+06  1455090.69
# 2012-05-04  1684519.99  1497462.72  1.542008e+06  1629391.28
# 2012-05-11  1611096.05  1497462.72  1.542008e+06  1604775.58
# 2012-05-18  1595901.87  1497462.72  1.542008e+06  1428218.27
# 2012-05-25  1555444.55  1497462.72  1.542008e+06  1466046.67
# 2012-06-01  1624477.58  1497462.72  1.542008e+06  1635078.41
# 2012-06-08  1697230.96  1497462.72  1.542008e+06  1588948.32
# 2012-06-15  1630607.00  1497462.72  1.542008e+06  1532114.86
# 2012-06-22  1527845.81  1497462.72  1.542008e+06  1438830.15
# 2012-06-29  1540421.49  1497462.72  1.542008e+06  1488538.09
# 2012-07-06  1769854.16  1497462.72  1.542008e+06  1534849.64
# 2012-07-13  1527014.04  1497462.72  1.542008e+06  1455119.97
# 2012-07-20  1497954.76  1497462.72  1.542008e+06  1396926.82
# 2012-07-27  1439123.71  1497462.72  1.542008e+06  1352219.79
# 2012-08-03  1631135.79  1497462.72  1.542008e+06  1624383.75
# 2012-08-10  1592409.97  1497462.72  1.542008e+06  1525147.09
# 2012-08-17  1597868.05  1497462.72  1.542008e+06  1530761.43
# 2012-08-24  1494122.38  1497462.72  1.542008e+06  1464693.46
# 2012-08-31  1582083.40  1497462.72  1.542008e+06  1550229.22
# 2012-09-07  1661767.33  1497462.72  1.542008e+06  1540471.24
# 2012-09-14  1517428.87  1497462.72  1.542008e+06  1514259.78
# 2012-09-21  1506126.06  1497462.72  1.542008e+06  1380020.27
# 2012-09-28  1437059.26  1497462.72  1.542008e+06  1394561.83
# 2012-10-05  1670785.97  1497462.72  1.542008e+06  1630989.95
# 2012-10-12  1573072.81  1497462.72  1.542008e+06  1493525.93
# 2012-10-19  1508068.77  1497462.72  1.542008e+06  1502562.78
# 2012-10-26  1493659.74  1497462.72  1.542008e+06  1445249.09

# %%
plt.figure(figsize=(12,8))
plt.plot(train['sales'], label='Train')
plt.plot(test['sales'], label='Test')
plt.plot(df_predictions['seasonal'], label='Seasonal')
#plt.plot(df_predictions['last'], label='Naive Forecast')
#plt.plot(df_predictions['simple_mean'], label='Historical Mean')
plt.legend(loc='best');

# %%
round(mean_squared_error(df_predictions['sales'], df_predictions['seasonal'], squared=False), 2)
# Out:
# 97900.47

# %% [markdown]
# ---
# ## Model 4: Simple Exponential Smoothing
#
# Smoothing just means using a moving average. Read more on moving averages from Hyndman [here](https://robjhyndman.com/papers/movingaverage.pdf).
#
# Simple exponential smoothing uses weighted averages where the weights decrease exponentially for older data points.
#
# $${\Large\hat y_{t+1} = \alpha y_t + \alpha (1-\alpha)y_{t-1} + \alpha(1-\alpha)^2 y_{t-2} + ...}$$
#
# The one-step-ahead forecast for time `t+1` is a weighted average of all of the observations in the series (`y1,…,yt`). The rate at which the weights decrease is controlled by the parameter, `α` (which is between 0 and 1).
#
# **Older values matter less.**

# %% [markdown]
# If alpha =.5:
#
# - What is the weight of the most recent observation (t)?
# - What is the weight of (t-1)?
# - What is the weight of (t-2)?

# %% [markdown]
# #### Let's use statsmodels for more advanced time series models to make life easier.

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
import statsmodels
statsmodels.__version__
# Out:
# '0.12.2'

# %%
ses = SimpleExpSmoothing(train['VQ1']).fit(smoothing_level=.5)
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %% [markdown]
# #### Summary info

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:                    VQ1   No. Observations:                 4229
# Model:             SimpleExpSmoothing   SSE                         111432.869
# Optimized:                       True   AIC                          13838.991
# Trend:                           None   BIC                          13851.690
# Seasonal:                        None   AICC                         13839.000
# Seasonal Periods:                None   Date:                 Thu, 03 Jun 2021
# Box-Cox:                        False   Time:                         13:50:40
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# initial_level              5.5149474                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %% [markdown]
# #### The best thing about statsmodels is the summary.
#
# Here you get lots of info: AIC, BIC, AICC, etc. 🎉

# %% [markdown]
# The AIC (Akaike Information Criterion) and BIC (Bayesian Information Criterion) above are measures of how well the model fits. Lower is better. They consider the complexity of the model - like adjusted R2.

# %% [markdown]
# #### Forecast with `.forecast`
#
# Here you can just pass an integer for the number of forecasts.

# %%
ses_forecast = ses.forecast(len(test))
ses_forecast
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# 4229    7.096709
# 4230    7.096709
# 4231    7.096709
# 4232    7.096709
# 4233    7.096709
#           ...
# 5292    7.096709
# 5293    7.096709
# 5294    7.096709
# 5295    7.096709
# 5296    7.096709
# Length: 1068, dtype: float64

# %%
df_predictions
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4  lastVQ1  simple_mean  ses
# DateStamp
# 2015-01-03    0   14    0    2   10    3   14    0        7      3.88035  NaN
# 2015-01-03    0   10   10   10    3    6    0    8        7      3.88035  NaN
# 2015-01-04    7    3    0    0    7    6   10    3        7      3.88035  NaN
# 2015-01-04   14    3    3    0    0    7    7   10        7      3.88035  NaN
# 2015-01-10   14    7    7    3    7    7   14    7        7      3.88035  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...      ...          ...  ...
# 2018-12-30    3    7    0    0    0    9    3    3        7      3.88035  NaN
# 2018-12-30    7    0    0    7    0   21    7    7        7      3.88035  NaN
# 2018-12-30    0   14    3    3    3    7    0   14        7      3.88035  NaN
# 2018-12-30    7    0    0    0    7   17    7    7        7      3.88035  NaN
# 2018-12-30    9   13    7   12    3    9   14    7        7      3.88035  NaN
#
# [1068 rows x 11 columns]

# %%
df_predictions['ses'] = 7.096709

# %%
df_predictions.head(2)
# Out:
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4  lastVQ1  simple_mean  \
# DateStamp
# 2015-01-03    0   14    0    2   10    3   14    0        7      3.88035
# 2015-01-03    0   10   10   10    3    6    0    8        7      3.88035
#
#                  ses
# DateStamp
# 2015-01-03  7.096709
# 2015-01-03  7.096709

# %% [markdown]
# #### Plot

# %%
plt.figure(figsize=(12,8))
plt.plot(train['VQ1'], label='Train')
plt.plot(test['VQ1'], label='Test')
plt.plot(df_predictions['lastVQ1'], label='Naive Forecast')
plt.plot(df_predictions['simple_mean'], label='Historical Mean')

plt.plot(df_predictions['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best');

# %% [markdown]
# You can play with the smoothing level, but SES forecasts the same number every time, so this isn't going to be a winner.

# %% [markdown]
# ---
# ## Model 5: Holt-Winters' (additive and multiplicative versions)
#
# - It's part of the exponential smoothing family of algorithms.
# - It's also called *Triple Exponential Smoothing*
#
# Holt-Winters' can handle treand and seasonality. It weights recent values more than old ones. This is a very strong classical time series model.
#
# #### Params to choose:
# - number of seasonal_periods
# - seasonal period effects additive or multiplicative
# - additive or multiplicative trend
# - dampening

# %%
train['VQ1.001'] = train['VQ1'] + .001
train
# Out:
# <ipython-input-51-f1dc1e6274e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['VQ1.001'] = train['VQ1'] + .001
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4  VQ1.001
# DateStamp
# 2000-09-03    7    6    7    7    6    3    7   14    7.001
# 2000-09-03    0    7    7   13    0    7    7    0    0.001
# 2000-09-03   10    0    0    7    7    0    3   10   10.001
# 2000-09-03    7    7    7    7    6   16   14    0    7.001
# 2000-09-03   10    3    3    0    0    0    0    0   10.001
# ...         ...  ...  ...  ...  ...  ...  ...  ...      ...
# 2015-12-27   10    6    0    7    0    3    7    7   10.001
# 2015-12-27    0    0    8    0    0   17   21    0    0.001
# 2015-12-27    0    3    7    7    3   16   13   17    0.001
# 2015-12-27   13    3   14    8    7    3    7    7   13.001
# 2015-12-28    7   10    0    3    7    3    2    8    7.001
#
# [4229 rows x 9 columns]

# %%
hww = ExponentialSmoothing(train['VQ1.001'], seasonal_periods=25,
trend = 'add', seasonal = 'add'
).fit()
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
hww.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                  VQ1.001   No. Observations:                 4229
# Model:             ExponentialSmoothing   SSE                          82608.476
# Optimized:                         True   AIC                          12627.209
# Trend:                         Additive   BIC                          12811.350
# Seasonal:                      Additive   AICC                         12627.681
# Seasonal Periods:                    25   Date:                 Thu, 03 Jun 2021
# Box-Cox:                          False   Time:                         14:06:47
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0001719                alpha                 True
# smoothing_trend              9.0272e-06                 beta                 True
# smoothing_seasonal            0.0029517                gamma                 True
# initial_level                 3.6240865                  l.0                 True
# initial_trend                 0.0001422                  b.0                 True
# initial_seasons.0             0.4798880                  s.0                 True
# initial_seasons.1            -0.7609392                  s.1                 True
# initial_seasons.2            -0.0080686                  s.2                 True
# initial_seasons.3            -0.6819816                  s.3                 True
# initial_seasons.4            -0.0567561                  s.4                 True
# initial_seasons.5             0.1178313                  s.5                 True
# initial_seasons.6             0.3095569                  s.6                 True
# initial_seasons.7            -0.0547022                  s.7                 True
# initial_seasons.8            -0.3732236                  s.8                 True
# initial_seasons.9             0.2345592                  s.9                 True
# initial_seasons.10            0.0279713                 s.10                 True
# initial_seasons.11            0.9758935                 s.11                 True
# initial_seasons.12           -0.0680873                 s.12                 True
# initial_seasons.13            0.3789287                 s.13                 True
# initial_seasons.14            0.4581680                 s.14                 True
# initial_seasons.15           -0.2969340                 s.15                 True
# initial_seasons.16            0.1100343                 s.16                 True
# initial_seasons.17           -0.7354050                 s.17                 True
# initial_seasons.18            0.0400332                 s.18                 True
# initial_seasons.19            0.0135684                 s.19                 True
# initial_seasons.20           -0.2305279                 s.20                 True
# initial_seasons.21            0.4389715                 s.21                 True
# initial_seasons.22            0.4569126                 s.22                 True
# initial_seasons.23            0.0350299                 s.23                 True
# initial_seasons.24           -0.3663971                 s.24                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_predictions['hw'] = hww.forecast(len(test))
df_predictions
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
#             VQ1  VQ2  VQ3  VQ4  HQ1  HQ2  HQ3  HQ4  lastVQ1  simple_mean  \
# DateStamp
# 2015-01-03    0   14    0    2   10    3   14    0        7      3.88035
# 2015-01-03    0   10   10   10    3    6    0    8        7      3.88035
# 2015-01-04    7    3    0    0    7    6   10    3        7      3.88035
# 2015-01-04   14    3    3    0    0    7    7   10        7      3.88035
# 2015-01-10   14    7    7    3    7    7   14    7        7      3.88035
# ...         ...  ...  ...  ...  ...  ...  ...  ...      ...          ...
# 2018-12-30    3    7    0    0    0    9    3    3        7      3.88035
# 2018-12-30    7    0    0    7    0   21    7    7        7      3.88035
# 2018-12-30    0   14    3    3    3    7    0   14        7      3.88035
# 2018-12-30    7    0    0    0    7   17    7    7        7      3.88035
# 2018-12-30    9   13    7   12    3    9   14    7        7      3.88035
#
#                  ses  hw
# DateStamp
# 2015-01-03  7.096709 NaN
# 2015-01-03  7.096709 NaN
# 2015-01-04  7.096709 NaN
# 2015-01-04  7.096709 NaN
# 2015-01-10  7.096709 NaN
# ...              ...  ..
# 2018-12-30  7.096709 NaN
# 2018-12-30  7.096709 NaN
# 2018-12-30  7.096709 NaN
# 2018-12-30  7.096709 NaN
# 2018-12-30  7.096709 NaN
#
# [1068 rows x 12 columns]

# %%
hw1 = ExponentialSmoothing(train['VQ1.001'], seasonal_periods=25,
trend = 'mul', seasonal = 'add'
).fit()
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
hw1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                  VQ1.001   No. Observations:                 4229
# Model:             ExponentialSmoothing   SSE                          91178.846
# Optimized:                         True   AIC                          13044.656
# Trend:                   Multiplicative   BIC                          13228.798
# Seasonal:                      Additive   AICC                         13045.128
# Seasonal Periods:                    25   Date:                 Thu, 03 Jun 2021
# Box-Cox:                          False   Time:                         14:03:26
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0050000                alpha                 True
# smoothing_trend               0.0050000                 beta                 True
# smoothing_seasonal            0.1066071                gamma                 True
# initial_level                 4.3362941                  l.0                 True
# initial_trend                 1.0031500                  b.0                 True
# initial_seasons.0             2.6647059                  s.0                 True
# initial_seasons.1            -4.3352941                  s.1                 True
# initial_seasons.2             5.6647059                  s.2                 True
# initial_seasons.3             2.6647059                  s.3                 True
# initial_seasons.4             5.6647059                  s.4                 True
# initial_seasons.5            -4.3352941                  s.5                 True
# initial_seasons.6            -4.3352941                  s.6                 True
# initial_seasons.7            -4.3352941                  s.7                 True
# initial_seasons.8            -4.3352941                  s.8                 True
# initial_seasons.9             9.6647059                  s.9                 True
# initial_seasons.10           -4.3352941                 s.10                 True
# initial_seasons.11           -4.3352941                 s.11                 True
# initial_seasons.12            2.6647059                 s.12                 True
# initial_seasons.13           -4.3352941                 s.13                 True
# initial_seasons.14            2.6647059                 s.14                 True
# initial_seasons.15           -4.3352941                 s.15                 True
# initial_seasons.16            2.6647059                 s.16                 True
# initial_seasons.17           -4.3352941                 s.17                 True
# initial_seasons.18           -4.3352941                 s.18                 True
# initial_seasons.19           -4.3352941                 s.19                 True
# initial_seasons.20            12.664706                 s.20                 True
# initial_seasons.21           -1.3352941                 s.21                 True
# initial_seasons.22           -4.3352941                 s.22                 True
# initial_seasons.23            2.6647059                 s.23                 True
# initial_seasons.24            9.6647059                 s.24                 True
# ---------------------------------------------------------------------------------
# """

# %%
hw2 = ExponentialSmoothing(train['VQ1.001'], seasonal_periods=25,
trend = 'mul', seasonal = 'mul'
).fit()
# Out:
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\cjmartin\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                  VQ1.001   No. Observations:                 4229
# Model:             ExponentialSmoothing   SSE                       82081181.828
# Optimized:                         True   AIC                          41813.025
# Trend:                   Multiplicative   BIC                          41997.167
# Seasonal:                Multiplicative   AICC                         41813.498
# Seasonal Periods:                    25   Date:                 Thu, 03 Jun 2021
# Box-Cox:                          False   Time:                         14:04:11
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0050000                alpha                 True
# smoothing_trend                  0.0001                 beta                 True
# smoothing_seasonal            0.8528571                gamma                 True
# initial_level                 4.3362941                  l.0                 True
# initial_trend                 1.0031500                  b.0                 True
# initial_seasons.0             1.6145123                  s.0                 True
# initial_seasons.1             0.0002306                  s.1                 True
# initial_seasons.2             2.3063472                  s.2                 True
# initial_seasons.3             1.6145123                  s.3                 True
# initial_seasons.4             2.3063472                  s.4                 True
# initial_seasons.5             0.0002306                  s.5                 True
# initial_seasons.6             0.0002306                  s.6                 True
# initial_seasons.7             0.0002306                  s.7                 True
# initial_seasons.8             0.0002306                  s.8                 True
# initial_seasons.9             3.2287939                  s.9                 True
# initial_seasons.10            0.0002306                 s.10                 True
# initial_seasons.11            0.0002306                 s.11                 True
# initial_seasons.12            1.6145123                 s.12                 True
# initial_seasons.13            0.0002306                 s.13                 True
# initial_seasons.14            1.6145123                 s.14                 True
# initial_seasons.15            0.0002306                 s.15                 True
# initial_seasons.16            1.6145123                 s.16                 True
# initial_seasons.17            0.0002306                 s.17                 True
# initial_seasons.18            0.0002306                 s.18                 True
# initial_seasons.19            0.0002306                 s.19                 True
# initial_seasons.20            3.9206289                 s.20                 True
# initial_seasons.21            0.6920656                 s.21                 True
# initial_seasons.22            0.0002306                 s.22                 True
# initial_seasons.23            1.6145123                 s.23                 True
# initial_seasons.24            3.2287939                 s.24                 True
# ---------------------------------------------------------------------------------
# """

# %%
hww

# %% [markdown]
# #### Plot

# %%
plt.figure(figsize=(12,8))
plt.plot(train['VQ1'], label='Train')
plt.plot(test['VQ1'], label='Test')
plt.plot(df_predictions['lastVQ1'], label='Naive Forecast')
plt.plot(df_predictions['simple_mean'], label='Historical Mean')

plt.plot(df_predictions['ses'], label='Simple Exponential Smoothing')
plt.plot(df_predictions['hww'], label="Holt-Winters'")
plt.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hww'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-631433674a14> in <module>
#       6
#       7 plt.plot(df_predictions['ses'], label='Simple Exponential Smoothing')
# ----> 8 plt.plot(df_predictions['hww'], label="Holt-Winters'")
#       9 plt.legend(loc='best');
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'hww'

# %% [markdown]
# ### Let's clean that up

# %%
plt.figure(figsize=(12,8))
plt.plot(train['sales'], label='Train')
plt.plot(test['sales'], label='Test')
plt.plot(df_predictions['hw'], label="Holt-Winters'")
plt.legend(loc='best');

# %% [markdown]
# Holy cow! 🐄

# %% [markdown]
# #### Evaluate

# %%
mean_squared_error(df_predictions['sales'], df_predictions['hw'], squared=False), 2)
# Out:
# 81491.11

# %% [markdown]
# ## Why did Holt-Winters' work well?

# %% [markdown]
# A time series dataset can be decomposed into its trend, seasonality, and residual components.
#
# Let's break down the components using statsmodels `seasonal_decompose` function.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
seasonal_decompose(games_Qscores, period=25).plot();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-bb833167048b> in <module>
#       1 from statsmodels.tsa.seasonal import seasonal_decompose
# ----> 2 seasonal_decompose(games_Qscores, period=25).plot();
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     185     for s, name in zip((seasonal, trend, resid, x),
#     186                        ('seasonal', 'trend', 'resid', None)):
# --> 187         results.append(pw.wrap(s.squeeze(), columns=name))
#     188     return DecomposeResult(seasonal=results[0], trend=results[1],
#     189                            resid=results[2], observed=results[3])
#
# ~\anaconda3\lib\site-packages\statsmodels\tools\validation\validation.py in wrap(self, obj, columns, append, trim_start, trim_end)
#     229                     new.append(append if c is None else f"{c}_{append}")
#     230                 columns = new
# --> 231             return pd.DataFrame(obj, columns=columns, index=index)
#     232         else:
#     233             raise ValueError("Can only wrap 1 or 2-d array_like")
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     204
#     205     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 206     index, columns = _get_axes(
#     207         values.shape[0], values.shape[1], index=index, columns=columns
#     208     )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\construction.py in _get_axes(N, K, index, columns)
#     464         columns = ibase.default_index(K)
#     465     else:
# --> 466         columns = ensure_index(columns)
#     467     return index, columns
#     468
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'seasonal' was passed

# %% [markdown]
# ---
# ## ARIMA

# %%
from pmdarima.utils import tsdisplay
from pmdarima.arima import auto_arima
model = auto_arima(train['VQ1'], m = 25, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[25] intercept   : AIC=inf, Time=34.50 sec
#  ARIMA(0,1,0)(0,0,0)[25] intercept   : AIC=27486.079, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[25] intercept   : AIC=26359.608, Time=1.88 sec
#  ARIMA(0,1,1)(0,0,1)[25] intercept   : AIC=inf, Time=17.54 sec
#  ARIMA(0,1,0)(0,0,0)[25]             : AIC=27484.079, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[25] intercept   : AIC=26359.143, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,1)[25] intercept   : AIC=26359.601, Time=2.16 sec
#  ARIMA(1,1,0)(1,0,1)[25] intercept   : AIC=26361.616, Time=2.58 sec
#  ARIMA(2,1,0)(0,0,0)[25] intercept   : AIC=25912.793, Time=0.32 sec
#  ARIMA(2,1,0)(1,0,0)[25] intercept   : AIC=25912.623, Time=2.67 sec
#  ARIMA(2,1,0)(2,0,0)[25] intercept   : AIC=25914.606, Time=15.52 sec
#  ARIMA(2,1,0)(1,0,1)[25] intercept   : AIC=25914.611, Time=9.50 sec
#  ARIMA(2,1,0)(0,0,1)[25] intercept   : AIC=25912.616, Time=2.65 sec
#  ARIMA(2,1,0)(0,0,2)[25] intercept   : AIC=25914.609, Time=12.57 sec
#  ARIMA(2,1,0)(1,0,2)[25] intercept   : AIC=25916.607, Time=19.01 sec
#  ARIMA(3,1,0)(0,0,1)[25] intercept   : AIC=25588.518, Time=5.07 sec
#  ARIMA(3,1,0)(0,0,0)[25] intercept   : AIC=25589.877, Time=0.42 sec
#  ARIMA(3,1,0)(1,0,1)[25] intercept   : AIC=inf, Time=22.69 sec
#  ARIMA(3,1,0)(0,0,2)[25] intercept   : AIC=25590.444, Time=19.88 sec
#  ARIMA(3,1,0)(1,0,0)[25] intercept   : AIC=25588.491, Time=4.52 sec
#  ARIMA(3,1,0)(2,0,0)[25] intercept   : AIC=25590.432, Time=23.60 sec
#  ARIMA(3,1,0)(2,0,1)[25] intercept   : AIC=25592.429, Time=27.75 sec
#  ARIMA(4,1,0)(1,0,0)[25] intercept   : AIC=25410.162, Time=6.91 sec
#  ARIMA(4,1,0)(0,0,0)[25] intercept   : AIC=25412.505, Time=0.66 sec
#  ARIMA(4,1,0)(2,0,0)[25] intercept   : AIC=25412.022, Time=34.94 sec
#  ARIMA(4,1,0)(1,0,1)[25] intercept   : AIC=25411.917, Time=26.65 sec
#  ARIMA(4,1,0)(0,0,1)[25] intercept   : AIC=25410.113, Time=6.25 sec
#  ARIMA(4,1,0)(0,0,2)[25] intercept   : AIC=25411.997, Time=73.54 sec
#  ARIMA(4,1,0)(1,0,2)[25] intercept   : AIC=25414.019, Time=65.54 sec
#  ARIMA(5,1,0)(0,0,1)[25] intercept   : AIC=25276.165, Time=14.60 sec
#  ARIMA(5,1,0)(0,0,0)[25] intercept   : AIC=25277.856, Time=2.22 sec
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-69-fb844581302e> in <module>
#       1 from pmdarima.utils import tsdisplay
#       2 from pmdarima.arima import auto_arima
# ----> 3 model = auto_arima(train['VQ1'], m = 25, trace=True)
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\auto.py in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     715         )
#     716
# --> 717     sorted_res = search.solve()
#     718     return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#     719
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in solve(self)
#     343             if P < max_P and \
#     344                     self.k < self.max_k and \
# --> 345                     self._do_fit((p, d, q), (P + 1, D, Q, m)):
#     346                 P += 1
#     347                 continue
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in _do_fit(self, order, seasonal_order, constant)
#     231             self.k += 1
#     232
# --> 233             fit, fit_time, new_ic = self._fit_arima(
#     234                 order=order,
#     235                 seasonal_order=seasonal_order,
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     504
#     505     try:
# --> 506         fit.fit(y, X=X, **fit_params)
#     507
#     508     # for non-stationarity errors or singular matrices, return None
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in fit(self, y, X, **fit_args)
#     480
#     481         # Internal call
# --> 482         self._fit(y, X, **fit_args)
#     483
#     484         # now make a forecast if we're validating to compute the
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in _fit(self, y, X, **fit_args)
#     401             with warnings.catch_warnings(record=False):
#     402                 warnings.simplefilter('ignore')
# --> 403                 fit, self.arima_res_ = _fit_wrapper()
#     404         else:
#     405             fit, self.arima_res_ = _fit_wrapper()
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in _fit_wrapper()
#     391             disp = fit_args.pop("disp", 0)
#     392
# --> 393             return arima, arima.fit(start_params=start_params,
#     394                                     method=method,
#     395                                     maxiter=_maxiter,
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     641         """
#     642         if start_params is None:
# --> 643             start_params = self.start_params
#     644             transformed = True
#     645             includes_fixed = True
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in start_params(self)
#     981         # Seasonal Parameters
#     982         _, params_seasonal_ar, params_seasonal_ma, params_seasonal_variance = (
# --> 983             self._conditional_sum_squares(
#     984                 endog, self.k_seasonal_ar, self.polynomial_seasonal_ar,
#     985                 self.k_seasonal_ma, self.polynomial_seasonal_ma,
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in _conditional_sum_squares(endog, k_ar, polynomial_ar, k_ma, polynomial_ma, k_trend, trend_data, warning_description)
#     835                     Y = endog[k:]
#     836                     X = lagmat(endog, k, trim='both')
# --> 837                     params_ar = np.linalg.pinv(X).dot(Y)
#     838                     residuals = Y - np.dot(X, params_ar)
#     839
#
# <__array_function__ internals> in pinv(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond, hermitian)
#    2000         return wrap(res)
#    2001     a = a.conjugate()
# -> 2002     u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2003
#    2004     # discard small singular values
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1658
#    1659         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1660         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1661         u = u.astype(result_t, copy=False)
#    1662         s = s.astype(_realType(result_t), copy=False)
#
# MemoryError: Unable to allocate 1.59 MiB for an array with shape (4178, 50) and data type float64

# %% [markdown]
# #### Pick a different store. Does the model perform similarly?

# %%
preds = model.predict(test.shape[0])

# %% [markdown]
# Note: Pandas has exponential weighted functions, rolling functions, and expanding window transformations. Great for looking at historical data, but statsmodels is far better for making a forecasts.

# %% [markdown]
# ## Check out the great free ebook:
# [Forecasting: Principles and Practice by
# Rob J Hyndman & George Athanasopoulos](https://otexts.com/fpp3/) to learn more about time series. Hyndman is also behind a lot of the time series code and strategy in an R package that Python packages use.
#
# Jason Brownlee also has a lot of great information and Python code on time series forecasting at [Machine Learning Mastery](https://machinelearningmastery.com/exponential-smoothing-for-time-series-forecasting-in-python/).

# %% [markdown]
# ## Summary
# - **Always sort your time series data by date**
# - **Make sure you aren't leaking information from the future into your training data**
# - Make baseline models first
# - Consider the tradeoffs between complexity and performance when choosing which model to use
# - Holt-Winters' Exponential Smoothing is really powerful and doesn't have too many parameters to choose.

# %% [markdown]
# ### Check for understanding
#
# - How can you keep from leaking test data into your training data?
# - Why does Holt-Winters' often work well on sales data?
