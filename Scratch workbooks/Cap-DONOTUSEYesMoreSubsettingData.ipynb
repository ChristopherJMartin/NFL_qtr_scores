# %%
import numpy as np
import pandas as pd

# %%
#Set viewing options
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)

# %%
games = pd.read_csv('data/MasterGames_2000to2019.csv')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5324 entries, 0 to 5323
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GameID       5324 non-null   object
#  1   Week         5324 non-null   int64
#  2   Day          5324 non-null   object
#  3   DateStamp    5324 non-null   object
#  4   Vteam        5324 non-null   object
#  5   VQ1          5324 non-null   int64
#  6   VQ2          5324 non-null   int64
#  7   VQ3          5324 non-null   int64
#  8   VQ4          5324 non-null   int64
#  9   Year         5324 non-null   int64
#  10  Hteam        5324 non-null   object
#  11  HQ1          5324 non-null   int64
#  12  HQ2          5324 non-null   int64
#  13  HQ3          5324 non-null   int64
#  14  HQ4          5324 non-null   int64
#  15  Date         5324 non-null   object
#  16  Time         5324 non-null   object
#  17  Winner/tie   5324 non-null   object
# ...

# %%
games.tail()
# Out:
#                     GameID  Week  Day   DateStamp    Vteam  VQ1  VQ2  VQ3  VQ4  Year   Hteam  HQ1  HQ2  HQ3  HQ4       Date    Time           Winner/tie Unnamed: 18            Loser/tie
# 5319  2019-DV-Vikings49ers   200  Sun  2020-01-12  Vikings    7    3    0    0  2019   49ers    7    7   10    3  1/12/2020  3:05PM   Kansas City Chiefs         NaN       Houston Texans
# 5320  2019-DV-TitansRavens   200  Sun  2020-01-12   Titans    7    7   14    0  2019  Ravens    0    6    0    6  1/12/2020  6:40PM    Green Bay Packers         NaN     Seattle Seahawks
# 5321  2019-CC-TitansChiefs   300  Sun  2020-01-19   Titans   10    7    0    7  2019  Chiefs    7   14    0   14  1/19/2020  3:05PM   Kansas City Chiefs         NaN     Tennessee Titans
# 5322  2019-CC-Packers49ers   300  Sun  2020-01-19  Packers    0    0    7   13  2019   49ers    7   20    7    3  1/19/2020  6:40PM  San Francisco 49ers         NaN    Green Bay Packers
# ...

# %%
#games_Bears = games[(games.Vteam == 'Bears') | games.Hteam == 'Bears') ]

# %%
games.columns
# Out:
# Index(['GameID', 'Week', 'Day', 'DateStamp', 'Vteam', 'VQ1', 'VQ2', 'VQ3',
#        'VQ4', 'Year', 'Hteam', 'HQ1', 'HQ2', 'HQ3', 'HQ4', 'Date', 'Time',
#        'Winner/tie', 'Unnamed: 18', 'Loser/tie'],
#       dtype='object')

# %%
games_nodates = games[['GameID', 'Week', 'Day','Vteam', 'VQ1', 'VQ2', 'VQ3',
       'VQ4', 'Year', 'Hteam', 'HQ1', 'HQ2', 'HQ3', 'HQ4']]
games_nodates.tail()
# Out:
#                     GameID  Week  Day    Vteam  VQ1  VQ2  VQ3  VQ4  Year   Hteam  HQ1  HQ2  HQ3  HQ4
# 5319  2019-DV-Vikings49ers   200  Sun  Vikings    7    3    0    0  2019   49ers    7    7   10    3
# 5320  2019-DV-TitansRavens   200  Sun   Titans    7    7   14    0  2019  Ravens    0    6    0    6
# 5321  2019-CC-TitansChiefs   300  Sun   Titans   10    7    0    7  2019  Chiefs    7   14    0   14
# 5322  2019-CC-Packers49ers   300  Sun  Packers    0    0    7   13  2019   49ers    7   20    7    3
# 5323   2019-SB-49ersChiefs   400  Sun    49ers    3    7   10    0  2019  Chiefs    7    3    0   21

# %%
games_nodates.iloc[730:775, :]
# Out:
#            GameID  Week  Day       Vteam  VQ1  VQ2  VQ3  VQ4  Year       Hteam  HQ1  HQ2  HQ3  HQ4
# 730  200212150cle    15  Sun       Colts    0    0   14   14  2002      Browns   13    3    0    7
# 731  200212150buf    15  Sun    Chargers    3    7    0    3  2002       Bills    7    6    0    7
# 732  200212150mia    15  Sun     Raiders    3    3    3    8  2002    Dolphins   10    7    3    3
# 733  200212150atl    15  Sun    Seahawks    7    0   14    3  2002     Falcons   14    3    0    7
# 734  200212150nor    15  Sun     Vikings   14   10    0    8  2002      Saints   10   10    3    8
# 735  200212150det    15  Sun  Buccaneers    3   10    0   10  2002       Lions    0   10    3    7
# 736  200212150chi    15  Sun        Jets    0    0   10    3  2002       Bears    0   10    7    3
# 737  200212150den    15  Sun      Chiefs    0    0   14   10  2002     Broncos   14    0   14    3
# ...

# %%
import re
for i in range(1,games_nodates.shape[0]):
    string = games_nodates.iloc[i,0]
    if string[4:6] == '01':
        games_nodates.iloc[i,8] = games_nodates.iloc[i,8] - 1
    elif string[4:6] == '02':
        games_nodates.iloc[i,8] = games_nodates.iloc[i,8] - 1
# Out:
# C:\Users\cjmartin\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
games_nodates.iloc[770:797, :]
# Out:
#            GameID  Week  Day       Vteam  VQ1  VQ2  VQ3  VQ4  Year       Hteam  HQ1  HQ2  HQ3  HQ4
# 770  200212290nyj    17  Sun     Packers    0   10    0    7  2002        Jets    0   14   14   14
# 771  200212290den    17  Sun   Cardinals    0    7    0    0  2002     Broncos    3    6    7   21
# 772  200212290chi    17  Sun  Buccaneers    0    6    0    9  2002       Bears    0    0    0    0
# 773  200212300ram    17  Mon       49ers    3   14    0    3  2002        Rams    0    0    3   28
# 774  200301040nyj   100  Sat       Colts    0    0    0    0  2002        Jets    7   17   10    7
# 775  200301040gnb   100  Sat     Falcons   14   10    3    0  2002     Packers    0    0    7    0
# 776  200301050pit   100  Sun      Browns    7   10    7    9  2002    Steelers    0    7    7   22
# 777  200301050sfo   100  Sun      Giants    7   21   10    0  2002       49ers    7    7    8   17
# ...

# %%
games_nodates_subb = games_nodates[games_nodates['Year'] == 2017]
games_nodates_subb.iloc[:17,]
# Out:
#                       GameID  Week  Day      Vteam  VQ1  VQ2  VQ3  VQ4  Year     Hteam  HQ1  HQ2  HQ3  HQ4
# 4501    2017-1-SaintsVikings     1  Sun     Saints    3    3    3   10  2017   Vikings    3   13    3   10
# 4502  2017-1-ChargersBroncos     1  Sun   Chargers    0    7    0   14  2017   Broncos    7    7   10    0
# 4503    2017-1-JaguarsTexans     1  Sun    Jaguars    3   16    7    3  2017    Texans    0    0    7    0
# 4504        2017-1-JetsBills     1  Sun       Jets    0    6    6    0  2017     Bills    0    7    7    7
# 4505   2017-1-EaglesRedskins     1  Sun     Eagles    7    9    3   11  2017  Redskins    0   14    3    0
# 4506   2017-1-CardinalsLions     1  Sun  Cardinals   10    0    7    6  2017     Lions    0    9    6   20
# 4507    2017-1-RaidersTitans     1  Sun    Raiders    7    6    3   10  2017    Titans    7    3    3    3
# 4508     2017-1-FalconsBears     1  Sun    Falcons    3    7    3   10  2017     Bears    0   10    0    7
# ...

# %%
games_nodates = games_nodates.drop(['Day'],axis=1)

# %%
games_nodates
# Out:
#                     GameID  Week     Vteam  VQ1  VQ2  VQ3  VQ4  Year     Hteam  HQ1  HQ2  HQ3  HQ4
# 0             200009030min     1     Bears    7    6    7    7  2000   Vikings    6    3    7   14
# 1             200009030kan     1     Colts    0    7    7   13  2000    Chiefs    0    7    7    0
# 2             200009030was     1  Panthers   10    0    0    7  2000  Redskins    7    0    3   10
# 3             200009030atl     1     49ers    7    7    7    7  2000   Falcons    6   16   14    0
# 4             200009030pit     1    Ravens   10    3    3    0  2000  Steelers    0    0    0    0
# ...                    ...   ...       ...  ...  ...  ...  ...   ...       ...  ...  ...  ...  ...
# 5319  2019-DV-Vikings49ers   200   Vikings    7    3    0    0  2019     49ers    7    7   10    3
# 5320  2019-DV-TitansRavens   200    Titans    7    7   14    0  2019    Ravens    0    6    0    6
# ...

# %%
games_nodates.to_csv('data/NoDatesMasterGames_2000to2019.csv', index=False)
